# %% [markdown]
# ### Objects

# %%
x=2+2 # Create a new object with a value of 4, referenced by 'x'.
print(x) # Print the value of the object.
print(5)
# Out:
# 4
# 5

# %%
x=2+2  # Create a new object with a value of 4, referenced by 'x'
print(type(x)) # Print the type of the object.

print(type('ABC')) # Create and print the type of a string object.
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = 2+2         #Create a new object with a value of 4, referenced by 'x'
print(id(x))    #Print the identity(memory address) of the x object

print(id('ABC')) # Create and print the identity of a string ( 'ABC') object.
# Out:
# 105807306302472
# 105807305993440

# %% [markdown]
# #### floating point

# %%
miles = float(input('Enter a distance in miles: '))
hours_to_fly = miles / 500.0
hours_to_drive = miles / 60.0

print(miles, 'miles would take:')
print (hours_to_fly, 'hours to fly' )
print(hours_to_drive, 'hours to drive' )
# Out:
# 500.0 miles would take:
# 1.0 hours to fly
# 8.333333333333334 hours to drive

# %%
miles = int(input('Enter a distance in miles: '))
hours_to_fly = miles // 500.0
hours_to_drive = miles / 60.0

print(miles, 'miles would take:')
print (hours_to_fly, 'hours to fly' )
print(hours_to_drive, 'hours to drive' )
# Out:
# 450 miles would take:
# 0.0 hours to fly
# 7.5 hours to drive

# %% [markdown]
# ## Overflow Error

# %%
print('2.0 to the power of 256  =', 2.0**256)
print('2.0 to the power of 512 =',  2.0**512)
print('2.0 to the power of 1024 =',  2.0**1024)
# Out:
# 2.0 to the power of 256  = 1.157920892373162e+77
# 2.0 to the power of 512 = 1.3407807929942597e+154
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 print('2.0 to the power of 256  =', 2.0**256)
#       2 print('2.0 to the power of 512 =',  2.0**512)
# ----> 3 print('2.0 to the power of 1024 =',  2.0**1024)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
"""computes the total cost of leasing a car given the down payment,
monthly rate, and number of months"""

down_payment = int(input('Enter down payment: ' ))
print('Down payment:', down_payment)
payment_per_month = int(input( 'Enter monthly payment: '))
print('Monthly payment:', payment_per_month)
num_months = int(input('Enter number of months: '))
print('Number of months:', num_months)

total_cost = down_payment + (payment_per_month * num_months)

print ('Total cost:', total_cost)
# Out:
# Down payment: 2000
# Monthly payment: 1000
# Number of months: 20
# Total cost: 22000

# %% [markdown]
# ### Raw String

# %%
my_string = 'This is a \n \'normal\' string\n'
my_raw_string = r'This is a \n\'raw\' string'

print(my_string)
print(my_raw_string)
# Out:
# This is a
#  'normal' string
#
# This is a \n\'raw\' string

# %%
ord('A')  # Returns the Unicode code point for the character 'A'
# Out:
# 65

# %%
ord('a')  # Returns the Unicode code point for the character 'a'
# Out:
# 97

# %%
ord(' ')  # Returns the Unicode code point for the character 'a'
# Out:
# 32

# %%
ord('일')  # Returns the Unicode code point for the character '일'
# Out:
# 51068

# %% [markdown]
# ### Divison and Modulo

# %%
user_val = int(input('Enter a three-digit number: '))
ones_digit = user_val % 10  # Ex: 927%10 is 7.
tmp_val = user_val // 10
tens_digit = tmp_val % 10   # Ex: tmp_val = 927//10 is 92%10 is 2.
tmp_val = tmp_val // 10
hundreds_digit = tmp_val % 10  # Ex: tmp_val=92//10=9, Then 9%10 is 9
print('The Number you entered is:', user_val)
print('The hundreds digit is:', hundreds_digit)
print('The tens digit is:', tens_digit)
print('The ones digit is:', ones_digit)
# Out:
# The Number you entered is: 563
# The hundreds digit is: 5
# The tens digit is: 6
# The ones digit is: 3
